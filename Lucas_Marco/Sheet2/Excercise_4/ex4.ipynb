# %% [markdown]
# (a)

# %%
m = 9.977e-26
T = 1450
k_B = 1.380649e-23

p(ν) = (m/(2*pi*k_B*T))^(3/2)*4*pi*ν^2*exp(-m*ν^2/(2*k_B*T))
# Out:
# p (generic function with 1 method)

# %%
using Plots

plot(p,legend=:false)
xlabel!("ν")
ylabel!("p(ν)")
